# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('haberman.csv', names= ["Age", "Operation-year" ,"Axil-Nodes" , "Survival-status"])

# %%
df.head()
# Out:
#    Age  Operation-year  Axil-Nodes  Survival-status
# 0   30              64           1                1
# 1   30              62           3                1
# 2   30              65           0                1
# 3   31              59           2                1
# 4   31              65           4                1

# %%
df.describe()
# Out:
#               Age  Operation-year  Axil-Nodes  Survival-status
# count  306.000000      306.000000  306.000000       306.000000
# mean    52.457516       62.852941    4.026144         1.264706
# std     10.803452        3.249405    7.189654         0.441899
# min     30.000000       58.000000    0.000000         1.000000
# 25%     44.000000       60.000000    0.000000         1.000000
# 50%     52.000000       63.000000    1.000000         1.000000
# 75%     60.750000       65.750000    4.000000         2.000000
# max     83.000000       69.000000   52.000000         2.000000

# %% [markdown]
# Total number of 306 people went through surgery at the mean age found 52, minimum age of 30 and maximum age of 83
# and found operation mean year at 62, Survival-status maximum at 1.0 and Axil-Nodes at mean 4.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              306 non-null    int64
#  1   Operation-year   306 non-null    int64
#  2   Axil-Nodes       306 non-null    int64
#  3   Survival-status  306 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
df.isnull()
# Out:
#        Age  Operation-year  Axil-Nodes  Survival-status
# 0    False           False       False            False
# 1    False           False       False            False
# 2    False           False       False            False
# 3    False           False       False            False
# 4    False           False       False            False
# ..     ...             ...         ...              ...
# 301  False           False       False            False
# 302  False           False       False            False
# 303  False           False       False            False
# 304  False           False       False            False
# 305  False           False       False            False
#
# [306 rows x 4 columns]

# %%
df.plot(kind='scatter',x='Age', y='Axil-Nodes')
plt.grid()
plt.show()

# %% [markdown]
# Age vs Axil-Nodes scatter plot shows at the age around 50 to 60 max number of Axil-Nodes are found

# %%
df['Age'].value_counts()
# Out:
# 52    14
# 54    13
# 50    12
# 47    11
# 53    11
# 43    11
# 57    11
# 49    10
# 65    10
# 55    10
# 38    10
# 41    10
# 42     9
# 45     9
# 61     9
# 59     8
# 63     8
# 56     7
# 58     7
# 62     7
# 48     7
# 46     7
# 44     7
# 70     7
# 34     7
# 51     6
# 67     6
# 39     6
# 37     6
# 60     6
# 66     5
# 64     5
# 69     4
# 72     4
# 30     3
# 40     3
# 31     2
# 68     2
# 36     2
# 35     2
# 33     2
# 73     2
# 74     2
# 71     1
# 75     1
# 76     1
# 77     1
# 78     1
# 83     1
# Name: Age, dtype: int64

# %%
df.plot(kind='scatter',x='Age', y='Survival-status')
plt.grid()
plt.show()

# %% [markdown]
# In the above scatter plot indicates the same number of peoples found in either 1 and 2 of survival-status

# %%
df.plot(kind='scatter',x='Operation-year', y='Axil-Nodes')
plt.grid()
plt.show()

# %% [markdown]
# In the above scatter plot shows the constant value for Axil-Nodes for operation-year

# %%
df['Axil-Nodes'].value_counts()
# Out:
# 0     136
# 1      41
# 2      20
# 3      20
# 4      13
# 6       7
# 7       7
# 8       7
# 5       6
# 9       6
# 13      5
# 11      4
# 14      4
# 19      3
# 23      3
# 22      3
# 15      3
# 10      3
# 20      2
# 12      2
# 17      1
# 18      1
# 16      1
# 21      1
# 24      1
# 25      1
# 28      1
# 30      1
# 35      1
# 46      1
# 52      1
# Name: Axil-Nodes, dtype: int64

# %%
df.plot(kind='line',x='Age', y='Axil-Nodes')
plt.grid()
plt.show()

# %% [markdown]
# The line indicates maximum Axial-Nodes occur at the age of 43

# %%
df.plot(kind='line',x='Age', y='Survival-status')
plt.grid()
plt.show()

# %% [markdown]
# Survival-status is at 2.0

# %%
df.plot(kind='line', x='Operation-year', y= 'Axil-Nodes')
plt.grid()
plt.show()

# %%
df['Survival-status'].value_counts()
# Out:
# 1    225
# 2     81
# Name: Survival-status, dtype: int64

# %% [markdown]
# Total number of people survived after surgery are 225
# and 81 people did not survived after surgery

# %%
df.plot(kind='bar',x='Age', y='Axil-Nodes')
plt.grid()
plt.show()

# %%
df.plot(kind='bar',x='Age', y='Survival-status')
plt.grid()
plt.show()

# %% [markdown]
# It shows the Survivsl-status is max at 1.0 and min at 2.0

# %%
df.plot(kind='bar', x='Operation-year', y= 'Axil-Nodes')
plt.grid()
plt.show()

# %%
df.plot(kind='hist',x='Age', y='Axil-Nodes')
plt.grid()
plt.show()

# %%
df.plot(kind='hist',x='Age', y='Survival-status')
plt.grid()
plt.show()

# %% [markdown]
# It shows the Survivsl-status is max at 1.0 and min at 2.0

# %%
df.plot(kind='hist', x='Operation-year', y= 'Axil-Nodes')
plt.grid()
plt.show()

# %%
df.plot(kind='box',x='Age', y='Axil-Nodes')
plt.grid()
plt.show()

# %%
df.plot(kind='box',x='Age', y='Survival-status')
plt.grid()
plt.show()

# %%
df.plot(kind='box', x='Operation-year', y= 'Axil-Nodes')
plt.grid()
plt.show()

# %%
df.plot(kind='pie',x='Age', y='Axil-Nodes')
plt.grid()
plt.show()

# %%
df.plot(kind='pie',x='Age', y='Survival-status')
plt.grid()
plt.show()

# %%
df.plot(kind='pie', x='Operation-year', y= 'Axil-Nodes')
plt.grid()
plt.show()
